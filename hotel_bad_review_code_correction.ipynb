# %% [markdown]
# <a href="https://colab.research.google.com/github/prejieunt/-NLP-hotel_review_sentiment_analysis_building_entiment_dictionary/blob/main/hotel_bad_review_code_correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
# !apt-get update -qq
# !apt-get unstall fonts-nanum* -qq
# Out:
# E: Invalid operation unstall

# %%
# konlpy 설치

# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2023-07-27 01:18:51--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2023-07-27 01:18:51--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc36bea97932796f4f86197e66c3.dl.dropboxusercontent.com/cd/0/get/CAqyx0TR662EhwZPeeJ4dTPOyzN0N7F-MKIso-6qXBop517SNv_2qZpAm7Gi6yNpiYnlhOHdKInkKi7kwc7i-GIyioGGHBoMqvTQr1rikUiCo9VCLeNcEULVgOkJH6SIeNYFPPIQ_OMyY3qmPIp_o8ZY/file?dl=1# [following]
# ...

# %%
# mecab 형태소 분석기 설치
# !pip install python-mecab-ko
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.9/573.9 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 6.8 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
# !pip install wordcloud

# %%
from mecab import MeCab

# %%
# 필요 라이브러리
import pandas as pd
import numpy as np
import os
import re
from tqdm import tqdm
from konlpy.tag import Okt
# from pykospacing import Spacing
from collections import Counter
from wordcloud import WordCloud


import matplotlib.pyplot as plt
import random
import seaborn as sns
import matplotlib.patches as patches
from matplotlib import rc
import seaborn as sns
#plt.rcParams["axes.unicode_minus"] = False
#rc("font", family="Malgun Gothic")
#%matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()

[f for f in sys_font if "Nanum" in f]
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf']

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt


path = "/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf"
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc("font", family=font_name)
#fm._rebuild()
# Out:
# NanumGothicCoding

# %%
# 형태소 분석기 'mecab' 선정 : 빠르고, 품사 분류가 잘 되어 있다. 🌞
mecab = MeCab()

# %%
import os

# %% [markdown]
# # 감성사전

# %%
# 긍정 단어 사전
satisfaction_with_traveling_together = ['여행', '최고', '가족', '추천', '숙소', '업그레이드', '수영장', '테마파크', '영장', '투숙', '따뜻', '친구', '워터', '지내', '파크', '숙박', '부모', '강추', '걱정', '즐기', '처음', '키즈', '정원', '박일', '계획', '온수풀', '머물', '선택', '여름', '하루', '프로그램', '마지막', '재밌', '일정', '선생', '액티비티', '요수', '세요', '날씨', '야외', '동반', '수영', '최적', '지인', '불꽃놀이', '모시', '디럭스', '트윈', '데리', '공연', '생일', '체험', '사우나', '유아', '엄마', '서울', '자녀', '신혼', '커플', '단위', '급하', '적극', '오랜만', '언제나', '예쁘', '월일', '기념', '물놀', '와이프', '남편', '어머니', '참여', '칭찬', '타입', '작년', '래드', '떠나', '아들', '놀이', '주년', '쿠지', '신랑', '신나', '머무르', '멋있', '숙시', '가끔', '라이브', '갑자기', '겨울', '예약', '어린아이', '강력', '운동', '리뷰', '여름휴가', '결혼', '여행객', '스위트룸', '여자', '스탠다드', '초등', '이동산', '업무', '공원', '스파', '적합', '연휴', '캠프', '종일', '식구']
# %% [markdown]
# # 나이브베이즈

# %%
review
# Out:
#                                                   review  target  \
# 0      친구 여기저기 돌아다니 는데 위치 도 좋 저녁 는 호텔 야외 수영장 실컷 놀 면서 ...     1.0
# 1      가족 여행 최적 화 된 호텔 입니다 멋진 공연 즐길 수 있 는 야외 수영장 즐길 수...     1.0
# 2      뷰 도 이쁘 고 로비 직원 도 너무너무 친절 합니다 더 캔버스 식사 했 는데 식사 ...     1.0
# 3      공항 셔틀버스 운행 고 있 어서 렌트 이용 기 좋 았 어요 택시 기본요금 면 중문 ...     1.0
# 4      초등 자녀 데리 고 가족 여행 다녀왔 어요 야외 수영장 국내 워터 파크 비교 해도 ...     1.0
# ...                                                  ...     ...
# 14675                           호텔 내 레스토랑 편의점 더 생겼으면 합니다    -1.0
# 14676                             방음 문제 있 는 듯 옆방 소음 잘 들림    -1.0
# 14677  숙박 객 피드백 느렸 다 호텔 내부 사정 인해 체크인 늦 질 경우 대처 는 방법 아...    -1.0
# 14678  여행 일정 빡빡 여수 영장 못 즐긴 게 아쉬웠 고 조식 못 먹 봐서 음 모르 겠 네...    -1.0
# 14679   행사 호텔 레스토랑 이용 할 수 없 다는 사실 체크인 할 안 내받 아서 당황 스러웠 음    -1.0
#
#                                             review_after
# 0      친구 여기저기 돌아다니 위치 저녁 야외 수영장 실컷 콘서트 추억 프론트 레스토랑 수...
# 1      가족 여행 최적 공연 야외 수영장 볼링장 거리 다양 체험 프로그램 프로그램 참여 휴...
# ...

# %%
# 나이브 베이즈에 대입하기 위하여 데이터를 튜플형태로 나타내준다
# 전체 데이터 값을 넣어주는게 맞나?...모델 정확하게 모르겠다 🚩

df_f = review[["review_after","target"]]

# 튜플형태로

tuples = [tuple(x) for x in df_f.values]
data = tuples

# %%
from collections import defaultdict
from pandas import read_table
import numpy as np
import math

# 전처리 된 단어들을 입력할 예정

class NaiveBayesClassifier:

    def __init__(self, k=0.5):
        self.k = k
        self.word_probs = []

    def count_words(self, training_set):
        stop_words = '제주도'
        # 학습데이터는 호텔 리뷰 본문(doc), 라벨(label)으로 구성
        counts = defaultdict(lambda : [0, 0])
        for doc, label in training_set:
            # 리뷰가 text일 때만 카운트
            if self.isNumber(doc) is False:
                # 리뷰를 띄어쓰기 단위로 토크나이징
                words = doc.split()

                for word in words:
                    text = str(word)
                    i = text.lower()
                    if(i not in stop_words):
                        # 라벨이 1이면 0값 지정
                        counts[i][0 if label == 1 else 1] += 1
        return counts
    # 예외 처리
    def isNumber(self, s):
        try:
            float(s)
            return True
        except ValueError:
            return False
    # 모델 결과 반환.
    def word_probabilities(self, counts, total_class0, total_class1, k):
        # 단어의 빈도수를 [단어, p(w|긍정), p(w|부정)] 형태로 반환
        return [(w,
                 (class0 + k) / (total_class0 + 2*k),
                 (class1 + k) / (total_class1 + 2*k))
                for w, (class0, class1) in counts.items()]

    def class0_probability(self, word_probs, doc):
        # input 띄어쓰기 처리
        docwords = doc.split()
        # 초기값은 모두 0으로 처리
        log_prob_if_class0 = log_prob_if_class1 = 0.0

        for word, prob_if_class0, prob_if_class1 in word_probs:

            # 만약 리뷰에 word가 나타나면 해당 단어가 나올 log 확률을 더해 줌
            if word in docwords:
                log_prob_if_class0 += math.log(prob_if_class0)
                log_prob_if_class1 += math.log(prob_if_class1)
            # 만약 리뷰에 word가 나타나지 않는다면 해당 단어가 나오지 않을 log 확률을 더해 줌.
            # 나오지 않을 확률은 log(1-나올 확률)로 계산
            else:
                log_prob_if_class0 += math.log(1.0 - prob_if_class0)
                log_prob_if_class1 += math.log(1.0 - prob_if_class1)

        prob_if_class0 = math.exp(log_prob_if_class0)
        prob_if_class1 = math.exp(log_prob_if_class1)
        return prob_if_class0 / (prob_if_class0 + prob_if_class1)
    # 모델 학습
    def train(self, corpus):
        training_set = corpus

        # calss0 = 긍정리뷰 수 / class1 = 부정리뷰 수
        num_class0 = 9645
        num_class1 = 5035

        # train
        word_counts = self.count_words(training_set)
        self.word_probs = self.word_probabilities(word_counts, num_class0, num_class1, self.k)
    # 모델 테스트
    def classify(self, doc):
        return self.class0_probability(self.word_probs, doc)

# %%
# 나이브 베이즈 학습
classifier = NaiveBayesClassifier()
classifier.train(data)

# %%
# 긍정 단어 가중치로 딕셔너리 만들기
dict_p = {}
for i in classifier.word_probs:
    dict_p[i[0]] = i[1]
# 부정 단어 가중치로 딕셔너리 만들기
dict_n = {}
for i in classifier.word_probs:
    dict_n[i[0]] = i[2]

# %%
dict_p
# Out:
# {'친구': 0.023792245490358698,
#  '여기저기': 0.003161932407215426,
#  '돌아다니': 0.003680281982168775,
#  '위치': 0.18302923491602738,
#  '저녁': 0.030841799709724237,
#  '야외': 0.015291312461123781,
#  '수영장': 0.1008189923284263,
#  '실컷': 0.0011922040223927017,
#  '콘서트': 0.0006738544474393531,
#  '추억': 0.016846361185983826,
#  '프론트': 0.02296288617043334,
#  '레스토랑': 0.010937176031515655,
#  '직원': 0.27197802197802196,
#  '친절': 0.29198631557122123,
#  '서비스': 0.10278872071324902,
#  '최고': 0.07023636740617872,
#  '가족': 0.10849056603773585,
#  '여행': 0.215788928053079,
#  '서담': 0.00015550487248600455,
#  '할머니': 0.0012958739373833713,
#  '부모': 0.016950031100974497,
#  '모시': 0.008034418411776902,
#  '구요': 0.007619738751814224,
#  '최적': 0.005753680281982169,
#  '공연': 0.007827078581795563,
#  '볼링장': 0.00171055359734605,
#  '거리': 0.044526228488492636,
#  '다양': 0.04058677171884719,
#  '체험': 0.00533900062201949,
#  '프로그램': 0.010937176031515655,
#  '참여': 0.004094961642131453,
#  '휴식': 0.009589467136636947,
# ...

# %%
dict_n
# Out:
# {'친구': 0.004269261318506751,
#  '여기저기': 0.0032764098490865767,
#  '돌아다니': 0.002283558379666402,
#  '위치': 0.03345909451945989,
#  '저녁': 0.017176330420969024,
#  '야외': 0.006850675138999206,
#  '수영장': 0.058478951548848294,
#  '실컷': 0.00029785544082605245,
#  '콘서트': 0.00029785544082605245,
#  '추억': 0.0020849880857823667,
#  '프론트': 0.02750198570293884,
#  '레스토랑': 0.005857823669579031,
#  '직원': 0.1073272438443209,
#  '친절': 0.04080619539316918,
#  '서비스': 0.05530182684670373,
#  '최고': 0.004864972200158856,
#  '가족': 0.029686258935663224,
#  '여행': 0.038026211278792695,
#  '서담': 9.928514694201747e-05,
#  '할머니': 0.0004964257347100874,
#  '부모': 0.002680698967434472,
#  '모시': 0.0014892772041302622,
#  '구요': 0.002283558379666402,
#  '최적': 9.928514694201747e-05,
#  '공연': 0.002283558379666402,
#  '볼링장': 0.0004964257347100874,
#  '거리': 0.013204924543288324,
#  '다양': 0.01102065131056394,
#  '체험': 0.0010921366163621922,
#  '프로그램': 0.001290706910246227,
#  '참여': 9.928514694201747e-05,
# ...

# %%
# 긍정 단어 사전
satisfaction_with_traveling_together = ['여행', '최고', '가족', '추천', '숙소', '업그레이드', '수영장', '테마파크', '영장', '투숙', '따뜻', '친구', '워터', '지내', '파크', '숙박', '부모', '강추', '걱정', '즐기', '처음', '키즈', '정원', '박일', '계획', '온수풀', '머물', '선택', '여름', '하루', '프로그램', '마지막', '재밌', '일정', '선생', '액티비티', '요수', '세요', '날씨', '야외', '동반', '수영', '최적', '지인', '불꽃놀이', '모시', '디럭스', '트윈', '데리', '공연', '생일', '체험', '사우나', '유아', '엄마', '서울', '자녀', '신혼', '커플', '단위', '급하', '적극', '오랜만', '언제나', '예쁘', '월일', '기념', '물놀', '와이프', '남편', '어머니', '참여', '칭찬', '타입', '작년', '래드', '떠나', '아들', '놀이', '주년', '쿠지', '신랑', '신나', '머무르', '멋있', '숙시', '가끔', '라이브', '갑자기', '겨울', '예약', '어린아이', '강력', '운동', '리뷰', '여름휴가', '결혼', '여행객', '스위트룸', '여자', '스탠다드', '초등', '이동산', '업무', '공원', '스파', '적합', '연휴', '캠프', '종일', '식구']
facility_Satisfaction = ['깨끗', '깔끔', '만족', '편안', '맛있', '아주', '편하', '이용', '가성', '조용', '시설', '괜찮', '전반', '서비스', '컨디션', '훌륭', '성비', '청결', '식사', '침구', '저렴', '부대시설', '해결', '조식', '분위기', '가능', '푹신', '아침', '여유', '완벽', '객실', '합리', '너무너무', '네요', '내부', '무료', '굉장히', '아늑', '저녁', '침구류', '뷔페', '적당', '나쁘', '안락', '규모', '장소', '구요', '나가', '최상', '잠자리', '아기', '포근', '꿀잠', '할인', '장점', '이벤트', '무난', '양호', '고요', '준비', '대비', '우수', '가격', '분리', '이닝', '대부분', '매일', '비갑', '갖추', '짬뽕', '편안히', '생각', '와인', '브런치', '퀄리티', '침대', '적당히', '이것저것', '맥주', '신선', '한잔', '전하', '다정', '충분', '성급', '메리어', '안정', '로비', '음식', '한적', '도시락', '디자인', '전체', '혜택', '모던', '폭신', '적절', '비교', '착하', '투고', '신축', '설면', '학회', '석식', '정갈', '워낙', '빵빵', '그냥저냥', '마루', '재미', '설치', '안심', '대여', '특가', '커피', '마시']
amenities_cost_dissatisfaction = ['칫솔', '치약', '부실', '당황', '면도기', '유료', '비용', '요금', '지불', '평범', '샴푸', '추가', '확인', '숙박비', '요구', '비누', '생수', '일회용품', '싱글', '린스', '위험', '건조', '불가', '음료', '사전', '금액', '인용', '부킹', '군요', '안함', '공지', '결제', '비치', '전문', '판매', '헤어', '어이없', '사이즈', '이용료', '별도', '바디', '요전', '세팅', '피트', '빙수', '머신', '인원', '닷컴', '망고', '센터', '니스', '내용', '전자레인지', '모양']
facility_dissatisfaction = ['소리', '주차장', '방음', '부족', '소음', '딱히', '주차', '협소', '공사', '애매', '옆방', '힘들', '복도', '작음', '그리', '엘리베이터', '복잡', '동선', '건물', '새벽', '밤새', '도로', '일부', '바람', '이터', '자리', '거려', '본관', '별관', '닫히', '비좁', '한숨', '엘레', '그다지', '짜증', '그닥', '중국', '구관', '좁음', '치우', '출구', '스프링', '오토바이', '예민', '높이', '입구', '맛없', '공간', '층간', '내려가', '시끄럽', '차장', '불만', '진입로', '출입문', '흡연', '전달', '들리', '흔들흔들', '민망', '건너편', '대화', '동동', '상권', '외부', '위층', '물소리', '유흥가', '떠드', '수용', '깜짝', '반면', '치중', '사무', '수질', '방해', '의문', '양쪽', '밤늦', '비닐하우스', '설계', '울리', '불평', '쿵쿵']
room_dissatisfaction = ['불편', '별로', '노후', '오래', '청소', '최악', '아쉽', '개선', '화장실', '아쉬움', '사람', '욕실', '문제', '특별히', '이해', '모르', '살짝', '미흡', '수압', '모텔', '세면대', '메뉴', '테이블', '실망', '가구', '느낌', '비싸', '콘센트', '따로', '필요', '의자', '투숙객', '낙후', '지저분', '샤워기', '아무래도', '요청', '변기', '굳이', '와이파이', '조명', '거울', '노후화', '어둡', '코로나', '심각', '딱딱', '교육', '인지', '룸서비스', '오픈', '운영', '예전', '들어가', '더럽', '연식', '이하', '보수', '바꾸', '답답', '떨어지', '불구', '그나마', '물때', '욕조', '수영복', '제한', '아무것', '차이', '종류', '한정', '사용', '배수', '조치', '불안', '걸레', '머리', '수준', '방안', '예상', '라도', '가시', '티비', '그렇', '마감', '용시', '천장', '성수기', '달랑', '금방', '보임', '이용객', '기본', '군데군데', '사악', '나오', '성인', '기능', '회전목마', '줄어들', '웃이', '창틀', '신경', '무뚝뚝', '한곳', '구조', '무섭', '고치']
unkindness = ['불친절', '전화', '고객', '태도', '연결', '비추', '마스크', '상황', '이야기', '체크', '잘못', '죄송', '연락', '말투', '데스크', '프론트', '반복', '형편없', '황당', '전기', '카운터', '연박', '입실', '한참', '이러', '일행', '서로', '플레인', '사과', '귀찮', '빨리', '답변', '똑같', '어수선', '퉁명', '소요', '정비', '착용', '안내', '표정', '포기', '차지', '커피포트', '아무리', '고생', '시스템', '카드', '휴대폰', '어렵', '자세', '쳐다보', '느림', '배치', '피해', '주의', '누르', '설명', '미숙']

# %%
# 토픽 모델링 단어에 대해 나이브베이지안 확률값 매핑
# 긍정 단어
satisfaction_with_traveling_together_dic  = {}

for topic in satisfaction_with_traveling_together:
    for word,value in dict_p.items():
        if(topic == word):
            satisfaction_with_traveling_together_dic[word] = value
print(len(satisfaction_with_traveling_together_dic))

topic


facility_Satisfaction_dic = {}
for topic in facility_Satisfaction :
    for word,value in dict_p.items():
        if(topic == word):
            facility_Satisfaction_dic[word] = value
print(len(facility_Satisfaction_dic))

location_convenience_dic = {}
for topic in location_convenience:
    for word,value in dict_p.items():
        if(topic == word):
            location_convenience_dic[word] = value
print(len(location_convenience_dic))

human_services_dic = {}
for topic in human_services:
    for word,value in dict_p.items():
        if(topic == word):
            human_services_dic[word] = value
print(len(human_services_dic))

surrounding_scenery_dic = {}
for topic in surrounding_scenery:
    for word,value in dict_p.items():
        if(topic == word):
            surrounding_scenery_dic[word] = value
print(len(surrounding_scenery_dic))

# 부정 단어
uncleanness_dic = {}
for topic in uncleanness:
    for word,value in dict_n.items():
        if(topic == word):
            uncleanness_dic[word] = value
print(len(uncleanness_dic))

amenities_cost_dissatisfaction_dic = {}
for topic in amenities_cost_dissatisfaction:
    for word,value in dict_n.items():
        if(topic == word):
            amenities_cost_dissatisfaction_dic[word] = value
print(len(amenities_cost_dissatisfaction_dic))

facility_dissatisfaction_dic = {}
for topic in facility_dissatisfaction:
    for word,value in dict_n.items():
        if(topic == word):
            facility_dissatisfaction_dic[word] = value
print(len(facility_dissatisfaction_dic))

room_dissatisfaction_dic = {}
for topic in room_dissatisfaction:
    for word,value in dict_n.items():
        if(topic == word):
            room_dissatisfaction_dic[word] = value
print(len(room_dissatisfaction_dic ))

unkindness_dic = {}
for topic in unkindness:
    for word,value in dict_p.items():
        if(topic == word):
            unkindness_dic[word] = value
print(len(unkindness_dic))
# Out:
# 111
# 116
# 80
# 64
# 28
# 96
# 54
# 84
# 108
# 58

# %%
unkindness_dic
# Out:
# {'불친절': 0.0005701845324486834,
#  '전화': 0.008345428156748911,
#  '고객': 0.010522496371552975,
#  '태도': 0.00171055359734605,
#  '연결': 0.007930748496786233,
#  '비추': 0.0005701845324486834,
#  '마스크': 0.0023325730872900685,
#  '상황': 0.004094961642131453,
#  '이야기': 0.002125233257308729,
#  '체크': 0.03768401409910844,
#  '잘못': 0.002850922662243417,
#  '죄송': 0.0005701845324486834,
#  '연락': 0.003265602322206096,
#  '말투': 0.00046651461745801366,
#  '데스크': 0.00523533070702882,
#  '프론트': 0.02296288617043334,
#  '반복': 0.00015550487248600455,
#  '형편없': 0.00015550487248600455,
#  '황당': 0.0008811942774206925,
#  '전기': 0.0020215633423180594,
#  '카운터': 0.0029545925772340867,
#  '연박': 0.0020215633423180594,
#  '입실': 0.0016068836823553805,
#  '한참': 0.0015032137673647108,
#  '이러': 0.00046651461745801366,
#  '일행': 0.0011922040223927017,
#  '서로': 0.0002591747874766743,
#  '플레인': 0.0006738544474393531,
#  '사과': 0.001399543852374041,
#  '귀찮': 0.0010885341074020319,
#  '빨리': 0.003265602322206096,
# ...

# %%
# 긍정리뷰 평가
def positvie_review(doc, name):
    doc = doc
    satisfaction_with_traveling_together = 0
    facility_Satisfaction = 0
    location_convenience = 0
    human_services = 0
    surrounding_scenery = 0


    words = doc.split()


    # 각 토픽별 점수 계산
    for word in words:
        for _,i in satisfaction_with_traveling_together_dic.items():
            if (word == _):
                satisfaction_with_traveling_together += i
        for _,i in facility_Satisfaction_dic.items():
            if (word == _):
                facility_Satisfaction += i
        for _,i in location_convenience_dic.items():
            if (word == _):
                location_convenience += i
        for _,i in human_services_dic.items():
            if (word == _):
                human_services += i
        for _,i in surrounding_scenery_dic.items():
            if (word == _):
                surrounding_scenery += i


    total = satisfaction_with_traveling_together + facility_Satisfaction + location_convenience + human_services + surrounding_scenery
    print('------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------')
    print('-------------------------------------------------------'+name+' 속성별 점수--------------------------------------------------------')
    print('동반 여행 시 만족도 : '+str(satisfaction_with_traveling_together)+'  | 시설 만족도 : '+str(facility_Satisfaction)+'  | 접근 편의성: '+str(location_convenience)+'  | 인적 서비스 : '+str(human_services)+' | 주변 경관 : '+str(surrounding_scenery))
    print('총 합계 : '+str(total))
    print('----------------------------------------------------------------------------------------------------------------------------------')

# %%
# 긍정 단어 사전
satisfaction_with_traveling_together = ['여행', '최고', '가족', '추천', '숙소', '업그레이드', '수영장', '테마파크', '영장', '투숙', '따뜻', '친구', '워터', '지내', '파크', '숙박', '부모', '강추', '걱정', '즐기', '처음', '키즈', '정원', '박일', '계획', '온수풀', '머물', '선택', '여름', '하루', '프로그램', '마지막', '재밌', '일정', '선생', '액티비티', '요수', '세요', '날씨', '야외', '동반', '수영', '최적', '지인', '불꽃놀이', '모시', '디럭스', '트윈', '데리', '공연', '생일', '체험', '사우나', '유아', '엄마', '서울', '자녀', '신혼', '커플', '단위', '급하', '적극', '오랜만', '언제나', '예쁘', '월일', '기념', '물놀', '와이프', '남편', '어머니', '참여', '칭찬', '타입', '작년', '래드', '떠나', '아들', '놀이', '주년', '쿠지', '신랑', '신나', '머무르', '멋있', '숙시', '가끔', '라이브', '갑자기', '겨울', '예약', '어린아이', '강력', '운동', '리뷰', '여름휴가', '결혼', '여행객', '스위트룸', '여자', '스탠다드', '초등', '이동산', '업무', '공원', '스파', '적합', '연휴', '캠프', '종일', '식구']
facility_Satisfaction = ['깨끗', '깔끔', '만족', '편안', '맛있', '아주', '편하', '이용', '가성', '조용', '시설', '괜찮', '전반', '서비스', '컨디션', '훌륭', '성비', '청결', '식사', '침구', '저렴', '부대시설', '해결', '조식', '분위기', '가능', '푹신', '아침', '여유', '완벽', '객실', '합리', '너무너무', '네요', '내부', '무료', '굉장히', '아늑', '저녁', '침구류', '뷔페', '적당', '나쁘', '안락', '규모', '장소', '구요', '나가', '최상', '잠자리', '아기', '포근', '꿀잠', '할인', '장점', '이벤트', '무난', '양호', '고요', '준비', '대비', '우수', '가격', '분리', '이닝', '대부분', '매일', '비갑', '갖추', '짬뽕', '편안히', '생각', '와인', '브런치', '퀄리티', '침대', '적당히', '이것저것', '맥주', '신선', '한잔', '전하', '다정', '충분', '성급', '메리어', '안정', '로비', '음식', '한적', '도시락', '디자인', '전체', '혜택', '모던', '폭신', '적절', '비교', '착하', '투고', '신축', '설면', '학회', '석식', '정갈', '워낙', '빵빵', '그냥저냥', '마루', '재미', '설치', '안심', '대여', '특가', '커피', '마시']
facility_dissatisfaction = ['소리', '주차장', '방음', '부족', '소음', '딱히', '주차', '협소', '공사', '애매', '옆방', '힘들', '복도', '작음', '그리', '엘리베이터', '복잡', '동선', '건물', '새벽', '밤새', '도로', '일부', '바람', '이터', '자리', '거려', '본관', '별관', '닫히', '비좁', '한숨', '엘레', '그다지', '짜증', '그닥', '중국', '구관', '좁음', '치우', '출구', '스프링', '오토바이', '예민', '높이', '입구', '맛없', '공간', '층간', '내려가', '시끄럽', '차장', '불만', '진입로', '출입문', '흡연', '전달', '들리', '흔들흔들', '민망', '건너편', '대화', '동동', '상권', '외부', '위층', '물소리', '유흥가', '떠드', '수용', '깜짝', '반면', '치중', '사무', '수질', '방해', '의문', '양쪽', '밤늦', '비닐하우스', '설계', '울리', '불평', '쿵쿵']
room_dissatisfaction = ['불편', '별로', '노후', '오래', '청소', '최악', '아쉽', '개선', '화장실', '아쉬움', '사람', '욕실', '문제', '특별히', '이해', '모르', '살짝', '미흡', '수압', '모텔', '세면대', '메뉴', '테이블', '실망', '가구', '느낌', '비싸', '콘센트', '따로', '필요', '의자', '투숙객', '낙후', '지저분', '샤워기', '아무래도', '요청', '변기', '굳이', '와이파이', '조명', '거울', '노후화', '어둡', '코로나', '심각', '딱딱', '교육', '인지', '룸서비스', '오픈', '운영', '예전', '들어가', '더럽', '연식', '이하', '보수', '바꾸', '답답', '떨어지', '불구', '그나마', '물때', '욕조', '수영복', '제한', '아무것', '차이', '종류', '한정', '사용', '배수', '조치', '불안', '걸레', '머리', '수준', '방안', '예상', '라도', '가시', '티비', '그렇', '마감', '용시', '천장', '성수기', '달랑', '금방', '보임', '이용객', '기본', '군데군데', '사악', '나오', '성인', '기능', '회전목마', '줄어들', '웃이', '창틀', '신경', '무뚝뚝', '한곳', '구조', '무섭', '고치']
unkindness = ['불친절', '전화', '고객', '태도', '연결', '비추', '마스크', '상황', '이야기', '체크', '잘못', '죄송', '연락', '말투', '데스크', '프론트', '반복', '형편없', '황당', '전기', '카운터', '연박', '입실', '한참', '이러', '일행', '서로', '플레인', '사과', '귀찮', '빨리', '답변', '똑같', '어수선', '퉁명', '소요', '정비', '착용', '안내', '표정', '포기', '차지', '커피포트', '아무리', '고생', '시스템', '카드', '휴대폰', '어렵', '자세', '쳐다보', '느림', '배치', '피해', '주의', '누르', '설명', '미숙']

# %%
#부정 리뷰 평가
def negative_review(doc, name):
    doc = doc
    uncleanness = 0
    amenities_cost_dissatisfaction = 0
    facility_dissatisfaction = 0
    room_dissatisfaction = 0
    unkindness = 0
    total = 0

    words = doc.split()

    # data_pos = nltk.pos_tag(words)
    # words_nnp = [word for word,pos in data_pos if pos in ['NN','NNP','VBG','JJ','JJS','JJR','RB','RBS','RBR']]
    # words = [w for w in words_nnp if not w in stopwords.words('english')]

    # 각 토픽별 점수 계산
    for word in words:
      for _,i in uncleanness_dic.items():
        if (word == _):
          uncleanness += i
      for _,i in amenities_cost_dissatisfaction_dic.items():
        if (word == _):
          amenities_cost_dissatisfaction += i
      for _,i in facility_dissatisfaction_dic.items():
        if (word == _):
          facility_dissatisfaction += i
      for _,i in room_dissatisfaction_dic.items():
        if (word == _):
          room_dissatisfaction += i
      for _,i in unkindness_dic.items():
        if (word == _):
          unkindness += i


    total = uncleanness + amenities_cost_dissatisfaction + facility_dissatisfaction + room_dissatisfaction + unkindness
    print('--------------------------------------------부정 리뷰 감성 분석----------------------------------------------------')
    print('---------------------------------------------'+name+' 속성별 점수----------------------------------------------')
    print('불청결  : '+str(uncleanness)+'  | 어메니티 및 비용 불만족성  : '+str(amenities_cost_dissatisfaction)+'  | 시설 불편성 : '+str(facility_dissatisfaction)+'  | 객실 불편성 : '+str(room_dissatisfaction)+'  | 불친절성 : '+str(unkindness))
    print('총 합계 : '+str(total))
    print('--------------------------------------------------------------------------------------------------------------')

# %%
#모든 호텔의 리뷰를 하나의 리스트에 넣어버리자

lotte_review_lst = df_all[df_all["name"] == "롯데 호텔 제주"]["detail"].to_list()
lotte_review_lst.append(df_all2[df_all2["name"] == "롯데 호텔 제주"]["detail_p"].to_list())
lotte_review_lst.append(df_all2[df_all2["name"] == "롯데 호텔 제주"]["detail_n"].to_list())


silla_review_lst = df_all[df_all["name"] == '제주 신라 호텔']["detail"].to_list()
silla_review_lst.append(df_all2[df_all2["name"] == '제주 신라 호텔']["detail_p"].to_list())
silla_review_lst.append(df_all2[df_all2["name"] == '제주 신라 호텔']["detail_n"].to_list())


whistlelark_review_lst = df_all[df_all["name"] == '호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션']["detail"].to_list()
whistlelark_review_lst.append(df_all2[df_all2["name"] == '호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션']["detail_p"].to_list())
whistlelark_review_lst.append(df_all2[df_all2["name"] == '호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션']["detail_n"].to_list())


best_review_lst = df_all[df_all["name"] == '메종 글래드 제주']["detail"].to_list()
best_review_lst.append(df_all2[df_all2["name"] == '메종 글래드 제주']["detail_p"].to_list())
best_review_lst.append(df_all2[df_all2["name"] == '메종 글래드 제주']["detail_n"].to_list())

ramada_review_lst = df_all[df_all["name"] == '라마다 제주 시티 호텔']["detail"].to_list()
ramada_review_lst.append(df_all2[df_all2["name"] == '라마다 제주 시티 호텔']["detail_p"].to_list())
ramada_review_lst.append(df_all2[df_all2["name"] == '라마다 제주 시티 호텔']["detail_n"].to_list())

ramada_c_review_lst = df_all[df_all["name"] == '라마다 프라자 제주 호텔']["detail"].to_list()
ramada_c_review_lst.append(df_all2[df_all2["name"] == '라마다 프라자 제주 호텔']["detail_p"].to_list())
ramada_c_review_lst.append(df_all2[df_all2["name"] == '라마다 프라자 제주 호텔']["detail_n"].to_list())


stay_review_lst = df_all[df_all["name"] == "신라스테이 제주"]["detail"].to_list()
stay_review_lst.append(df_all2[df_all2["name"] == "신라스테이 제주"]["detail_p"].to_list())
stay_review_lst.append(df_all2[df_all2["name"] == "신라스테이 제주"]["detail_n"].to_list())


shinhwa_review_lst = df_all[df_all["name"] == '신화관 제주신화월드 호텔앤리조트']["detail"].to_list()
shinhwa_review_lst.append(df_all2[df_all2["name"] == '신화관 제주신화월드 호텔앤리조트']["detail_p"].to_list())
shinhwa_review_lst.append(df_all2[df_all2["name"] == '신화관 제주신화월드 호텔앤리조트']["detail_n"].to_list())


grand_review_lst = df_all[df_all["name"] == "더 그랜드 섬오름"]["detail"].to_list()
grand_review_lst.append(df_all2[df_all2["name"] == "더 그랜드 섬오름"]["detail_p"].to_list())
grand_review_lst.append(df_all2[df_all2["name"] == "더 그랜드 섬오름"]["detail_n"].to_list())


landing_review_lst = df_all[df_all["name"] == "랜딩관 제주신화월드 호텔앤리조트"]["detail"].to_list()
landing_review_lst.append(df_all2[df_all2["name"] == "랜딩관 제주신화월드 호텔앤리조트"]["detail_p"].to_list())
landing_review_lst.append(df_all2[df_all2["name"] == "랜딩관 제주신화월드 호텔앤리조트"]["detail_n"].to_list())

# %%
lotte_review_lst = np.hstack(lotte_review_lst)
lotte_review_lst = lotte_review_lst.tolist()
lotte_review_lst = ','.join(lotte_review_lst)


silla_review_lst = np.hstack(silla_review_lst)
silla_review_lst = silla_review_lst.tolist()
silla_review_lst = ','.join(silla_review_lst)

whistlelark_review_lst = np.hstack(whistlelark_review_lst)
whistlelark_review_lstt = whistlelark_review_lst.tolist()
whistlelark_review_lst = ','.join(whistlelark_review_lst)

best_review_lst = np.hstack(best_review_lst)
best_review_lst = best_review_lst.tolist()
best_review_lst = ','.join(best_review_lst)

ramada_review_lst = np.hstack(ramada_review_lst)
ramada_review_lst = ramada_review_lst.tolist()
ramada_review_lst = ','.join(ramada_review_lst)

ramada_c_review_lst = np.hstack(ramada_c_review_lst)
ramada_c_review_lst = ramada_c_review_lst.tolist()
ramada_c_review_lst = ','.join(ramada_c_review_lst)

stay_review_lst = np.hstack(stay_review_lst)
stay_review_lst = stay_review_lst.tolist()
stay_review_lst = ','.join(stay_review_lst)

shinhwa_review_lst = np.hstack(shinhwa_review_lst)
shinhwa_review_lst = shinhwa_review_lst.tolist()
shinhwa_review_lst = ','.join(shinhwa_review_lst)

grand_review_lst = np.hstack(grand_review_lst)
grand_review_lst = grand_review_lst.tolist()
grand_review_lst = ','.join(grand_review_lst)

landing_review_lst = np.hstack(landing_review_lst)
landing_review_lst = landing_review_lst.tolist()
landing_review_lst = ','.join(landing_review_lst)

# %%
lotte_review_lst
# Out:
# '친구랑 여기저기 돌아다니는데 위치도 좋구 저녁에는 호텔 야외수영장에서 실컷 놀면서 콘서트 보고 멋진 추억 쌓고 왔습니당프론트나 레스토랑 수영장 호텔 내 모든 직원분들이 다 친절하셨어요롯데호텔 직원분들 친절도 서비스 최고입니다가족여행으로도 좋다고 해서 담번엔 가족여행으로 할머니랑 부모님 모시고 오려구요다음에도 멋진 추억 쌓을수 있었으면 좋겠습니당ㅎㅎㅎ ,가족여행에 최적화된 호텔입니다. 멋진 공연과 함께 즐길 수 있는 야외수영장과 아이들과 같이 즐길 수 있는 볼링장 등 호텔 내에서 즐길 거리가 많습니다.다양한 체험프로그램이 있어 아이들이 프로그램에 참여하는 동안 휴식시간이 생겨서 좋았어요.침구는 호텔 자체 브랜드인 거 같은데 푹신하고 쾌적해서 꿀잠잤어요.침대가드 같은 대여용품도 갯수 관계없이 무료입니다.직원분들도 만날 때마다 웃는 얼굴로 인사해주셔서 기분 좋았습니다.,뷰도 너무 이쁘고 로비 직원들도 너무너무 친절합니다~~ 더캔버스에서 식사했는데 식사도 맛있고 수영장도 물도 따뜻해서 아기랑도 저녁에 이용하기 좋았어요 호텔에서 바로 색달해변으로 내려가는 길도 있어서 산책하기도 좋았답니다. 저녁 야경도 너무 이뻐서 사진 찍기에도 좋았네요! 이번에는 친구들 아이 데리고 놀러갔었는데 다음번엔 부모님 모시고 한번 더 방문하겠습니다~,공항 셔틀버스를 운행하고 있어서 렌트 없이 이용하기 좋았어요택시 기본요금이면 중문에 식당들도 충분이 이동하기 편했습니다가족 단위로 많이들 이용하지만 커플이나 친구들끼리 와도 좋을거같아요 ! 풍차 앞에서 바라보는 호텔 야경이 너무 예뻐서 매일 밤 산책할때 정말 행복했어요 오래되었지만 관리가 깔끔하게 잘되어있고 너무나도 친절한 직원들 덕분에 편하게 쉬었습니다 다음에 꼭 다시 갈거에요!!,초등자녀 데리고 가족 여행다녀왔어요야외수영장이 국내 어느 워터파크와 비교해도 빠지지 않을만큼 시설이 훌륭합니다 유아풀 성인풀 샤워장 락카룸등 필요한 시설이 모두 갖추어져 있고로비에 근무하는 직원들도 친절합니다프런트에서 체크인 할때도 아이가 있고 야외수영장 이용계
# ...

# %% [markdown]
# # 긍정 리뷰 감성 분석

# %%
positvie_review(lotte_review_lst, "롯데 호텔")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------롯데 호텔 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 13.294578063445977  | 시설 만족도 : 24.884356209827907  | 접근 편의성: 2.3259382127306663  | 인적 서비스 : 8.800176238855489 | 주변 경관 : 0.6436346672195729
# 총 합계 : 49.948683392079616
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(silla_review_lst, "제주 신라 호텔")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------제주 신라 호텔 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 7.753991291727134  | 시설 만족도 : 16.429245283018872  | 접근 편의성: 1.799502384408045  | 인적 서비스 : 5.349574953348536 | 주변 경관 : 0.06489736678415924
# 총 합계 : 31.397211279286743
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(whistlelark_review_lst, "호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 9.09055567074434  | 시설 만족도 : 16.22143893842007  | 접근 편의성: 9.19629898403482  | 인적 서비스 : 5.031982168774621 | 주변 경관 : 1.7481857764876632
# 총 합계 : 41.28846153846152
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
best_review_lst 메종 글래드 제주
ramada_review_lst 라마다 제주 시티 호텔
ramada_c_review_lst 라마다 프라자 제주 호텔
stay_review_lst 신라스테이 제주
shinhwa_review_lst 신화관 제주신화월드 호텔앤리조트
grand_review_lst 더 그랜드 섬오름
landing_review_lst 랜딩관 제주신화월드 호텔앤리조트
# Out:
#   File "<ipython-input-223-00362ffe8605>", line 1
#     best_review_lst 메종 글래드 제주
#                     ^
# SyntaxError: invalid syntax

# %%
positvie_review(best_review_lst, "메종 글래드 제주")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------메종 글래드 제주 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 17.563394153016798  | 시설 만족도 : 31.853358905245713  | 접근 편의성: 8.614607091022185  | 인적 서비스 : 14.099108438731088 | 주변 경관 : 0.18064482687124198
# 총 합계 : 72.31111341488703
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(ramada_review_lst, "라마다 제주 시티 호텔")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------라마다 제주 시티 호텔 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 9.19448476052249  | 시설 만족도 : 29.488233464648616  | 접근 편의성: 11.821946921003514  | 인적 서비스 : 7.4864710760937205 | 주변 경관 : 0.24963715529753258
# 총 합계 : 58.24077337756588
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(ramada_c_review_lst, "라마다 프라자 제주 호텔")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------라마다 프라자 제주 호텔 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 15.411880572257903  | 시설 만족도 : 39.497978436657725  | 접근 편의성: 7.502125233257306  | 인적 서비스 : 8.575523533070704 | 주변 경관 : 2.4396122745179345
# 총 합계 : 73.42712004976158
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(stay_review_lst, "신라스테이 제주")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------신라스테이 제주 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 2.832210242587601  | 시설 만족도 : 21.12678830603362  | 접근 편의성: 6.767572050590917  | 인적 서비스 : 6.78654364503421 | 주변 경관 : 0.1916856728177483
# 총 합계 : 37.70479991706409
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(shinhwa_review_lst, "신화관 제주신화월드 호텔앤리조트")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------신화관 제주신화월드 호텔앤리조트 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 28.986211901306376  | 시설 만족도 : 73.02348123574556  | 접근 편의성: 6.464233879328213  | 인적 서비스 : 18.7845739166494 | 주변 경관 : 0.24497200912295258
# 총 합계 : 127.5034729421525
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(grand_review_lst, "더 그랜드 섬오름")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------더 그랜드 섬오름 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 7.319873522703703  | 시설 만족도 : 21.219469210035257  | 접근 편의성: 3.0260211486626605  | 인적 서비스 : 5.603358905245699 | 주변 경관 : 2.14399751192204
# 총 합계 : 39.31272029856936
# ----------------------------------------------------------------------------------------------------------------------------------

# %%
positvie_review(landing_review_lst, "랜딩관 제주신화월드 호텔앤리조트")
# Out:
# ------------------------------------------------------긍정 리뷰 감성 분석--------------------------------------------------------------
# -------------------------------------------------------랜딩관 제주신화월드 호텔앤리조트 속성별 점수--------------------------------------------------------
# 동반 여행 시 만족도 : 25.453711382956733  | 시설 만족도 : 71.16934480613737  | 접근 편의성: 7.111445158614963  | 인적 서비스 : 21.17053701015967 | 주변 경관 : 0.2268816089570807
# 총 합계 : 125.13191996682585
# ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 부정 리뷰 감성 분석

# %%
negative_review(lotte_review_lst, "롯데 호텔")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------롯데 호텔 속성별 점수----------------------------------------------
# 불청결  : 0.4022041302621129  | 어메니티 및 비용 불만족성  : 0.10405083399523431  | 시설 불편성 : 0.4500595710881652  | 객실 불편성 : 2.6413820492454323  | 불친절성 : 0.3348538254198632
# 총 합계 : 3.9325504100108075
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(silla_review_lst, "제주 신라 호텔")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------제주 신라 호텔 속성별 점수----------------------------------------------
# 불청결  : 0.32793884034948373  | 어메니티 및 비용 불만족성  : 0.1391977760127085  | 시설 불편성 : 0.7417593328038126  | 객실 불편성 : 2.6777204130262113  | 불친절성 : 0.15358697905867713
# 총 합계 : 4.040203341250893
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(whistlelark_review_lst, "호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------호텔 휘슬락 바이 베스트웨스턴 시그니처 컬렉션 속성별 점수----------------------------------------------
# 불청결  : 1.2181294678316124  | 어메니티 및 비용 불만족성  : 0.38274424146147734  | 시설 불편성 : 2.8460087370929315  | 객실 불편성 : 3.8844320889594908  | 불친절성 : 0.19883889695210444
# 총 합계 : 8.530153432297617
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(best_review_lst, "메종 글래드 제주")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------메종 글래드 제주 속성별 점수----------------------------------------------
# 불청결  : 0.9471803018268466  | 어메니티 및 비용 불만족성  : 0.3970413026211279  | 시설 불편성 : 3.2461278792692605  | 객실 불편성 : 5.113284352660843  | 불친절성 : 0.6489218328840972
# 총 합계 : 10.352555669262175
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(ramada_review_lst, "라마다 제주 시티 호텔")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------라마다 제주 시티 호텔 속성별 점수----------------------------------------------
# 불청결  : 1.2902104845115168  | 어메니티 및 비용 불만족성  : 0.5354447974583002  | 시설 불편성 : 5.577045274027005  | 객실 불편성 : 3.588959491660046  | 불친절성 : 0.8783951897159449
# 총 합계 : 11.870055237372814
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(ramada_c_review_lst, "라마다 프라자 제주 호텔")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------라마다 프라자 제주 호텔 속성별 점수----------------------------------------------
# 불청결  : 1.2350079428117555  | 어메니티 및 비용 불만족성  : 0.2593328038125496  | 시설 불편성 : 2.0809173947577446  | 객실 불편성 : 7.170373312152507  | 불친절성 : 0.5948579722164629
# 총 합계 : 11.34048942575102
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(stay_review_lst, "신라스테이 제주")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------신라스테이 제주 속성별 점수----------------------------------------------
# 불청결  : 1.0954130262112791  | 어메니티 및 비용 불만족성  : 0.17414614773629866  | 시설 불편성 : 5.351667990468623  | 객실 불편성 : 3.697378872120731  | 불친절성 : 0.4432407215426083
# 총 합계 : 10.761846758079539
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(shinhwa_review_lst, "신화관 제주신화월드 호텔앤리조트")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------신화관 제주신화월드 호텔앤리조트 속성별 점수----------------------------------------------
# 불청결  : 2.4566123907863378  | 어메니티 및 비용 불만족성  : 0.4515488482922955  | 시설 불편성 : 3.181294678316122  | 객실 불편성 : 8.757247815726778  | 불친절성 : 0.7661725067385443
# 총 합계 : 15.612876239860077
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(grand_review_lst, "더 그랜드 섬오름")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------더 그랜드 섬오름 속성별 점수----------------------------------------------
# 불청결  : 0.7081016679904689  | 어메니티 및 비용 불만족성  : 0.1522041302621128  | 시설 불편성 : 1.8497815726767268  | 객실 불편성 : 4.134332803812548  | 불친절성 : 0.3808832676757205
# 총 합계 : 7.225303442417577
# --------------------------------------------------------------------------------------------------------------

# %%
negative_review(landing_review_lst, "랜딩관 제주신화월드 호텔앤리조트")
# Out:
# --------------------------------------------부정 리뷰 감성 분석----------------------------------------------------
# ---------------------------------------------랜딩관 제주신화월드 호텔앤리조트 속성별 점수----------------------------------------------
# 불청결  : 2.54438046068308  | 어메니티 및 비용 불만족성  : 0.5382247815726766  | 시설 불편성 : 3.710087370929305  | 객실 불편성 : 9.46713661636221  | 불친절성 : 0.8801575782707856
# 총 합계 : 17.139986807818058
# --------------------------------------------------------------------------------------------------------------
